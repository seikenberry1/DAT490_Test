# %%
print("Some stuff")
# Out:
# Some stuff

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
print("Heya")
# Out:
# Heya

# %%
x = np.linspace(-10,10,100)
y = x**3

plt.plot(x,y)

# %%
x = np.linspace(0,10,100)
y = x**2

plt.plot(x,y)
